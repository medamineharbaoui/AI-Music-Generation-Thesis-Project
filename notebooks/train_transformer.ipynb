# %%
# Import required libraries
import glob
import pickle
import numpy as np
from music21 import converter, instrument, note, chord
from keras.models import Model
from keras.layers import Input, Dense, Dropout, Embedding, Flatten
from keras.layers import MultiHeadAttention, LayerNormalization
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam
import tensorflow as tf
import os

def train_transformer():
    """ Trains a Transformer model to generate music """
    notes = get_notes()  # Get all notes and chords from MIDI files
    vocab_size = len(set(notes))  # Vocabulary size
    network_input, network_output = prepare_sequences(notes, vocab_size)
    model = create_transformer(network_input, vocab_size)
    train_model(model, network_input, network_output)

def get_notes():
    """ Gets all notes and chords with their durations from MIDI files """
    notes = []
    
   
    midi_path = "/kaggle/input/full-51/*.mid"  
    for file in glob.glob(midi_path):
        midi = converter.parse(file)
        print(f"Parsing {file}")

        notes_to_parse = None
        try:
            s2 = instrument.partitionByInstrument(midi)
            notes_to_parse = s2.parts[0].recurse()
        except:
            notes_to_parse = midi.flat.notes

        for element in notes_to_parse:
            duration = element.duration.quarterLength
            if duration < 0.75:
                duration_class = 'short'
            elif duration < 1.5:
                duration_class = 'medium'
            else:
                duration_class = 'long'

            if isinstance(element, note.Note):
                note_str = f"{str(element.pitch)}_{duration_class}"
                notes.append(note_str)
            elif isinstance(element, chord.Chord):
                chord_str = f"{'.'.join(str(n) for n in element.normalOrder)}_{duration_class}"
                notes.append(chord_str)

    # Save notes to Kaggle's working directory
    os.makedirs('/kaggle/working/transformer_outputs/model_notes', exist_ok=True)
    with open('/kaggle/working/transformer_outputs/model_notes/full51_notes.pkl', 'wb') as filepath:
        pickle.dump(notes, filepath)

    return notes

def prepare_sequences(notes, vocab_size):
    """ Prepares the sequences used by the Transformer """
    sequence_length = 25
    note_names = sorted(set(notes))
    note_to_int = dict((note, number) for number, note in enumerate(note_names))

    network_input = []
    network_output = []

    for i in range(len(notes) - sequence_length):
        input_sequence = notes[i:i + sequence_length]
        output_sequence = notes[i + sequence_length]
        network_input.append([note_to_int[char] for char in input_sequence])
        network_output.append(note_to_int[output_sequence])

    network_input = np.array(network_input)
    network_output = to_categorical(network_output, num_classes=vocab_size)

    return network_input, network_output

def create_transformer(network_input, vocab_size):
    """ Creates the Transformer model structure """
    d_model = 256  # Embedding dimension
    num_heads = 8  # Number of attention heads
    dff = 512      # Feed-forward layer dimension

    input_length = network_input.shape[1]
    input_length = int(input_length)

    print(f"input_length: {input_length}")
    print(f"type(input_length): {type(input_length)}")

    inputs = Input(shape=(input_length,))
    embedding = Embedding(input_dim=vocab_size, output_dim=d_model)(inputs)

    # Positional Embedding
    positions = tf.range(start=0, limit=input_length, delta=1)
    positions = positions[tf.newaxis, :]
    position_embedding_layer = Embedding(input_dim=input_length, output_dim=d_model)
    position_embeddings = position_embedding_layer(positions)

    x = embedding + position_embeddings

    # Transformer block
    attn_output = MultiHeadAttention(num_heads=num_heads, key_dim=d_model)(x, x)
    attn_output = Dropout(0.1)(attn_output)
    out1 = LayerNormalization(epsilon=1e-6)(x + attn_output)

    ffn_output = Dense(dff, activation='relu')(out1)
    ffn_output = Dense(d_model)(ffn_output)
    ffn_output = Dropout(0.1)(ffn_output)
    out2 = LayerNormalization(epsilon=1e-6)(out1 + ffn_output)

    out_flat = Flatten()(out2)
    outputs = Dense(vocab_size, activation='softmax')(out_flat)

    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='categorical_crossentropy')

    return model

def train_model(model, network_input, network_output):
    """ Trains the Transformer model """
    # Save weights every epoch in Kaggle's working directory
    os.makedirs('/kaggle/working/transformer_outputs/weights', exist_ok=True)
    filepath = "/kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch{epoch:02d}-loss{loss:.4f}.keras"

    checkpoint = ModelCheckpoint(
        filepath,
        monitor='loss',
        verbose=1,
        save_best_only=False,  # Save every epoch
        save_weights_only=False,  # Save full model
        mode='min'
    )
    callbacks_list = [checkpoint]

    model.fit(network_input, network_output, epochs=100, batch_size=64, callbacks=callbacks_list)

if __name__ == '__main__':
    train_transformer()
# Out:
# 2025-05-19 20:45:19.115856: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747687519.358738      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747687519.427894      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Parsing /kaggle/input/full-51/burg_geschwindigkeit.mid
# Parsing /kaggle/input/full-51/br_im2.mid
# Parsing /kaggle/input/full-51/alb_se2.mid
# Parsing /kaggle/input/full-51/muss_7.mid
# Parsing /kaggle/input/full-51/mendel_op62_3.mid
# Parsing /kaggle/input/full-51/mendel_op19_6.mid
# Parsing /kaggle/input/full-51/scn16_4.mid
# Parsing /kaggle/input/full-51/schubert_D850_4.mid
# Parsing /kaggle/input/full-51/elise.mid
# Parsing /kaggle/input/full-51/mz_570_2.mid
# Parsing /kaggle/input/full-51/burg_perlen.mid
# Parsing /kaggle/input/full-51/chpn_op10_e05.mid
# Parsing /kaggle/input/full-51/mendel_op30_4.mid
# Parsing /kaggle/input/full-51/chpn-p11.mid
# Parsing /kaggle/input/full-51/schub_d760_4.mid
# Parsing /kaggle/input/full-51/liz_et_trans8.mid
# Parsing /kaggle/input/full-51/brahms_opus1_4.mid
# Parsing /kaggle/input/full-51/chpn-p18.mid
# Parsing /kaggle/input/full-51/liz_et4.mid
# Parsing /kaggle/input/full-51/scn16_2.mid
# Parsing /kaggle/input/full-51/alb_esp4.mid
# Parsing /kaggle/input/full-51/brahms_opus1_1.mid
# Parsing /kaggle/input/full-51/grieg_once_upon_a_time.mid
# Parsing /kaggle/input/full-51/liz_rhap10.mid
# Parsing /kaggle/input/full-51/haydn_9_1.mid
# Parsing /kaggle/input/full-51/alb_esp1.mid
# Parsing /kaggle/input/full-51/gra_esp_4.mid
# Parsing /kaggle/input/full-51/haydn_43_1.mid
# Parsing /kaggle/input/full-51/burg_sylphen.mid
# Parsing /kaggle/input/full-51/muss_5.mid
# Parsing /kaggle/input/full-51/bor_ps1.mid
# Parsing /kaggle/input/full-51/deb_menu.mid
# Parsing /kaggle/input/full-51/mz_333_2.mid
# Parsing /kaggle/input/full-51/muss_3.mid
# Parsing /kaggle/input/full-51/deb_prel.mid
# Parsing /kaggle/input/full-51/appass_2.mid
# Parsing /kaggle/input/full-51/gra_esp_2.mid
# Parsing /kaggle/input/full-51/ty_september.mid
# Parsing /kaggle/input/full-51/ty_november.mid
# Parsing /kaggle/input/full-51/gra_esp_3.mid
# Parsing /kaggle/input/full-51/ty_oktober.mid
# Parsing /kaggle/input/full-51/beethoven_opus10_3.mid
# Parsing /kaggle/input/full-51/haydn_7_2.mid
# Parsing /kaggle/input/full-51/bor_ps7.mid
# Parsing /kaggle/input/full-51/schuim-2.mid
# Parsing /kaggle/input/full-51/bor_ps3.mid
# Parsing /kaggle/input/full-51/grieg_butterfly.mid
# Parsing /kaggle/input/full-51/debussy_cc_6.mid
# Parsing /kaggle/input/full-51/grieg_zwerge.mid
# Parsing /kaggle/input/full-51/scn15_12.mid
# Parsing /kaggle/input/full-51/mz_331_2.mid
# input_length: 25
# type(input_length): <class 'int'>
# I0000 00:00:1747687704.156548      35 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747687711.860030      95 service.cc:148] XLA service 0x7dc7c8014250 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1747687711.860780      95 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1747687712.347372      95 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   16/1086 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - loss: 8.8060
# I0000 00:00:1747687715.368400      95 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.6727
# Epoch 1: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch01-loss4.9646.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 23s 13ms/step - loss: 5.6720
# Epoch 2/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.0520
# Epoch 2: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch02-loss3.9340.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 4.0514
# Epoch 3/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1424
# Epoch 3: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch03-loss3.1074.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 3.1422
# Epoch 4/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.2994
# Epoch 4: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch04-loss2.3330.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 2.2996
# Epoch 5/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6454
# Epoch 5: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch05-loss1.7234.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 1.6458
# Epoch 6/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1849
# Epoch 6: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch06-loss1.2816.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 1.1854
# Epoch 7/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8866
# Epoch 7: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch07-loss0.9829.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.8871
# Epoch 8/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6900
# Epoch 8: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch08-loss0.7741.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.6905
# Epoch 9/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5380
# Epoch 9: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch09-loss0.6289.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.5385
# Epoch 10/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4611
# Epoch 10: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch10-loss0.5264.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.4615
# Epoch 11/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3979
# Epoch 11: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch11-loss0.4558.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.3983
# Epoch 12/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3580
# Epoch 12: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch12-loss0.4163.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.3583
# Epoch 13/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3205
# Epoch 13: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch13-loss0.3711.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.3208
# Epoch 14/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2950
# Epoch 14: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch14-loss0.3410.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.2953
# Epoch 15/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2650
# Epoch 15: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch15-loss0.3066.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.2652
# Epoch 16/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2577
# Epoch 16: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch16-loss0.2952.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.2579
# Epoch 17/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2387
# Epoch 17: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch17-loss0.2784.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.2389
# Epoch 18/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2368
# Epoch 18: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch18-loss0.2581.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.2370
# Epoch 19/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2067
# Epoch 19: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch19-loss0.2492.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.2069
# Epoch 20/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2201
# Epoch 20: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch20-loss0.2453.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.2202
# Epoch 21/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1915
# Epoch 21: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch21-loss0.2281.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1917
# Epoch 22/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1906
# Epoch 22: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch22-loss0.2139.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1908
# Epoch 23/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1817
# Epoch 23: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch23-loss0.2087.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1819
# Epoch 24/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1730
# Epoch 24: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch24-loss0.2025.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1731
# Epoch 25/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1670
# Epoch 25: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch25-loss0.1915.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1671
# Epoch 26/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1650
# Epoch 26: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch26-loss0.1838.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1651
# Epoch 27/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1626
# Epoch 27: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch27-loss0.1925.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1628
# Epoch 28/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1543
# Epoch 28: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch28-loss0.1732.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1545
# Epoch 29/100
# 1085/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1506
# Epoch 29: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch29-loss0.1697.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1506
# Epoch 30/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1465
# Epoch 30: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch30-loss0.1637.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1466
# Epoch 31/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1336
# Epoch 31: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch31-loss0.1588.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1337
# Epoch 32/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1404
# Epoch 32: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch32-loss0.1590.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1405
# Epoch 33/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1284
# Epoch 33: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch33-loss0.1462.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1285
# Epoch 34/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1238
# Epoch 34: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch34-loss0.1492.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1239
# Epoch 35/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1391
# Epoch 35: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch35-loss0.1492.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1392
# Epoch 36/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1174
# Epoch 36: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch36-loss0.1412.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1175
# Epoch 37/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1146
# Epoch 37: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch37-loss0.1326.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1147
# Epoch 38/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1240
# Epoch 38: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch38-loss0.1383.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1241
# Epoch 39/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1126
# Epoch 39: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch39-loss0.1301.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1127
# Epoch 40/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1163
# Epoch 40: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch40-loss0.1347.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1164
# Epoch 41/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1042
# Epoch 41: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch41-loss0.1235.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1043
# Epoch 42/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1068
# Epoch 42: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch42-loss0.1239.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1069
# Epoch 43/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1082
# Epoch 43: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch43-loss0.1202.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1082
# Epoch 44/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1048
# Epoch 44: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch44-loss0.1186.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1048
# Epoch 45/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1027
# Epoch 45: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch45-loss0.1160.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1028
# Epoch 46/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1027
# Epoch 46: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch46-loss0.1204.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1028
# Epoch 47/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1098
# Epoch 47: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch47-loss0.1161.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.1098
# Epoch 48/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0888
# Epoch 48: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch48-loss0.1041.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0888
# Epoch 49/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0913
# Epoch 49: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch49-loss0.1064.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0913
# Epoch 50/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0981
# Epoch 50: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch50-loss0.1112.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0982
# Epoch 51/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0923
# Epoch 51: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch51-loss0.1102.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0924
# Epoch 52/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0894
# Epoch 52: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch52-loss0.1020.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0895
# Epoch 53/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0977
# Epoch 53: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch53-loss0.1087.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0977
# Epoch 54/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0957
# Epoch 54: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch54-loss0.0995.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0957
# Epoch 55/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0869
# Epoch 55: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch55-loss0.0989.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0869
# Epoch 56/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0840
# Epoch 56: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch56-loss0.0955.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0841
# Epoch 57/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0811
# Epoch 57: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch57-loss0.0959.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0812
# Epoch 58/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0929
# Epoch 58: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch58-loss0.1040.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0929
# Epoch 59/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0850
# Epoch 59: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch59-loss0.0915.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0851
# Epoch 60/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0817
# Epoch 60: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch60-loss0.0921.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0817
# Epoch 61/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0834
# Epoch 61: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch61-loss0.0927.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0834
# Epoch 62/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0788
# Epoch 62: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch62-loss0.0916.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0788
# Epoch 63/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0776
# Epoch 63: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch63-loss0.0914.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0777
# Epoch 64/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0762
# Epoch 64: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch64-loss0.0883.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0763
# Epoch 65/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0771
# Epoch 65: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch65-loss0.0887.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0772
# Epoch 66/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0783
# Epoch 66: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch66-loss0.0867.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0783
# Epoch 67/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0851
# Epoch 67: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch67-loss0.0889.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0851
# Epoch 68/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0643
# Epoch 68: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch68-loss0.0811.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0644
# Epoch 69/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0764
# Epoch 69: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch69-loss0.0900.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0765
# Epoch 70/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0722
# Epoch 70: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch70-loss0.0808.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0723
# Epoch 71/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0712
# Epoch 71: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch71-loss0.0818.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0712
# Epoch 72/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0718
# Epoch 72: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch72-loss0.0844.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0719
# Epoch 73/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0706
# Epoch 73: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch73-loss0.0815.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0707
# Epoch 74/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0649
# Epoch 74: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch74-loss0.0757.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0649
# Epoch 75/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0736
# Epoch 75: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch75-loss0.0865.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0737
# Epoch 76/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0761
# Epoch 76: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch76-loss0.0838.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0762
# Epoch 77/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0659
# Epoch 77: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch77-loss0.0753.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0660
# Epoch 78/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0652
# Epoch 78: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch78-loss0.0787.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0652
# Epoch 79/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0721
# Epoch 79: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch79-loss0.0788.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0722
# Epoch 80/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0687
# Epoch 80: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch80-loss0.0735.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0687
# Epoch 81/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0695
# Epoch 81: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch81-loss0.0815.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0696
# Epoch 82/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0597
# Epoch 82: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch82-loss0.0693.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0598
# Epoch 83/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0656
# Epoch 83: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch83-loss0.0746.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0656
# Epoch 84/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0695
# Epoch 84: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch84-loss0.0803.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0695
# Epoch 85/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0602
# Epoch 85: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch85-loss0.0703.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0603
# Epoch 86/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0616
# Epoch 86: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch86-loss0.0692.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0616
# Epoch 87/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0604
# Epoch 87: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch87-loss0.0695.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0605
# Epoch 88/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0726
# Epoch 88: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch88-loss0.0757.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0726
# Epoch 89/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0595
# Epoch 89: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch89-loss0.0652.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0596
# Epoch 90/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0647
# Epoch 90: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch90-loss0.0710.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0648
# Epoch 91/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0629
# Epoch 91: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch91-loss0.0714.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0629
# Epoch 92/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0578
# Epoch 92: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch92-loss0.0698.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0578
# Epoch 93/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0733
# Epoch 93: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch93-loss0.0774.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0733
# Epoch 94/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0580
# Epoch 94: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch94-loss0.0662.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0580
# Epoch 95/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0579
# Epoch 95: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch95-loss0.0663.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0579
# Epoch 96/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0659
# Epoch 96: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch96-loss0.0735.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0660
# Epoch 97/100
# 1085/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0607
# Epoch 97: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch97-loss0.0679.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0607
# Epoch 98/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0573
# Epoch 98: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch98-loss0.0646.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0573
# Epoch 99/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0606
# Epoch 99: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch99-loss0.0679.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0606
# Epoch 100/100
# 1081/1086 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0578
# Epoch 100: saving model to /kaggle/working/transformer_outputs/weights/weights_transformer-full_51-epoch100-loss0.0642.keras
# 1086/1086 ━━━━━━━━━━━━━━━━━━━━ 12s 11ms/step - loss: 0.0578
